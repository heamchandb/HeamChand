# %% [markdown]
# # Uploading files from local drive

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-3bd8fd9e-ffbc-4519-896a-0596dc1aa24f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3bd8fd9e-ffbc-4519-896a-0596dc1aa24f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Heam Chand - Project Week1.csv to Heam Chand - Project Week1 (2).csv

# %% [markdown]
# # Load the necessary libraries. Import and load the dataset with a name uber_drives .

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Q1. Show the last 10 records of the dataset. (2 point)

# %%
uber_drives  = pd.read_csv('Heam Chand - Project Week1.csv')
uber_drives.tail(10)
# Out:
#            START_DATE*         END_DATE*  ... MILES*         PURPOSE*
# 1145  12/30/2016 10:15  12/30/2016 10:33  ...    2.8  Errand/Supplies
# 1146  12/30/2016 11:31  12/30/2016 11:56  ...    2.9  Errand/Supplies
# 1147  12/30/2016 15:41  12/30/2016 16:03  ...    4.6  Errand/Supplies
# 1148  12/30/2016 16:45  12/30/2016 17:08  ...    4.6          Meeting
# 1149  12/30/2016 23:06  12/30/2016 23:10  ...    0.8   Customer Visit
# 1150   12/31/2016 1:07   12/31/2016 1:14  ...    0.7          Meeting
# 1151  12/31/2016 13:24  12/31/2016 13:42  ...    3.9   Temporary Site
# 1152  12/31/2016 15:03  12/31/2016 15:38  ...   16.2          Meeting
# 1153  12/31/2016 21:32  12/31/2016 21:50  ...    6.4   Temporary Site
# 1154  12/31/2016 22:08  12/31/2016 23:51  ...   48.2   Temporary Site
#
# [10 rows x 7 columns]

# %% [markdown]
# ## Q2. Show the first 10 records of the dataset. (2 points)

# %%
uber_drives.head(10)
# Out:
#         START_DATE*         END_DATE*  ... MILES*         PURPOSE*
# 0  01-01-2016 21:11  01-01-2016 21:17  ...    5.1   Meal/Entertain
# 1  01-02-2016 01:25  01-02-2016 01:37  ...    5.0              NaN
# 2  01-02-2016 20:25  01-02-2016 20:38  ...    4.8  Errand/Supplies
# 3  01-05-2016 17:31  01-05-2016 17:45  ...    4.7          Meeting
# 4  01-06-2016 14:42  01-06-2016 15:49  ...   63.7   Customer Visit
# 5  01-06-2016 17:15  01-06-2016 17:19  ...    4.3   Meal/Entertain
# 6  01-06-2016 17:30  01-06-2016 17:35  ...    7.1          Meeting
# 7  01-07-2016 13:27  01-07-2016 13:33  ...    0.8          Meeting
# 8  01-10-2016 08:05  01-10-2016 08:25  ...    8.3          Meeting
# 9  01-10-2016 12:17  01-10-2016 12:44  ...   16.5   Customer Visit
#
# [10 rows x 7 columns]

# %% [markdown]
# ## Q3. Show the dimension(number of rows and columns) of the dataset. (2 points)

# %%
print('No. of rows : ',len(uber_drives))
print('\nNo. of columns : ',len(uber_drives.columns))
# Out:
# No. of rows :  1155
#
# No. of columns :  7

# %% [markdown]
# ## Q4. Show the size (Total number of elements) of the dataset. (2 points)

# %%
uber_drives.size
# Out:
# 8085

# %% [markdown]
# ## Q5. Display the information about all the variables of the data set. What can you infer from the output?(1 +2 points)
#
# #### Hint: Information includes - Total number of columns,variable data-types, number of non-null values in a variable, and usage

# %%
uber_drives.info()
#There are 7 coloumns, and variable data-types of type "Object" except for MILES* which is of type 'float' with a total of 653 non-null values, the memory usage is of 63.3+ KB
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1155 entries, 0 to 1154
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1155 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1155 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %% [markdown]
# ## Q6. Check for missing values. (2 points)
#
# ####  Note: Output should contain only one boolean value

# %%
uber_drives.notnull()
# Out:
#       START_DATE*  END_DATE*  CATEGORY*  START*  STOP*  MILES*  PURPOSE*
# 0            True       True       True    True   True    True      True
# 1            True       True       True    True   True    True     False
# 2            True       True       True    True   True    True      True
# 3            True       True       True    True   True    True      True
# 4            True       True       True    True   True    True      True
# ...           ...        ...        ...     ...    ...     ...       ...
# 1150         True       True       True    True   True    True      True
# 1151         True       True       True    True   True    True      True
# 1152         True       True       True    True   True    True      True
# 1153         True       True       True    True   True    True      True
# 1154         True       True       True    True   True    True      True
#
# [1155 rows x 7 columns]

# %% [markdown]
# ## Q7. How many missing values are present in the entire dataset? (2 points)

# %%
uber_drives.isnull().sum()
# Out:
# START_DATE*      0
# END_DATE*        0
# CATEGORY*        0
# START*           0
# STOP*            0
# MILES*           0
# PURPOSE*       502
# dtype: int64

# %% [markdown]
# ## Q8. Get the summary of the original data. (2 points).
#
# #### Hint: Summary includes- Count,Mean, Std, Min, 25%,50%,75% and max

# %%
uber_drives.describe()
# Out:
#             MILES*
# count  1155.000000
# mean     10.566840
# std      21.579106
# min       0.500000
# 25%       2.900000
# 50%       6.000000
# 75%      10.400000
# max     310.300000

# %% [markdown]
# ## Q9. Drop the missing values and store the data in a new dataframe (name it"df") (2-points)
#
# #### Note: Dataframe "df" will not contain any missing value

# %%
df = uber_drives.dropna()
df
# Out:
#            START_DATE*         END_DATE*  ... MILES*         PURPOSE*
# 0     01-01-2016 21:11  01-01-2016 21:17  ...    5.1   Meal/Entertain
# 2     01-02-2016 20:25  01-02-2016 20:38  ...    4.8  Errand/Supplies
# 3     01-05-2016 17:31  01-05-2016 17:45  ...    4.7          Meeting
# 4     01-06-2016 14:42  01-06-2016 15:49  ...   63.7   Customer Visit
# 5     01-06-2016 17:15  01-06-2016 17:19  ...    4.3   Meal/Entertain
# ...                ...               ...  ...    ...              ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  ...    0.7          Meeting
# 1151  12/31/2016 13:24  12/31/2016 13:42  ...    3.9   Temporary Site
# 1152  12/31/2016 15:03  12/31/2016 15:38  ...   16.2          Meeting
# 1153  12/31/2016 21:32  12/31/2016 21:50  ...    6.4   Temporary Site
# 1154  12/31/2016 22:08  12/31/2016 23:51  ...   48.2   Temporary Site
#
# [653 rows x 7 columns]

# %% [markdown]
# ## Q10. Check the information of the dataframe(df). (1 points)
#
# #### Hint: Information includes - Total number of columns,variable data-types, number of non-null values in a variable, and usage

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 653 entries, 0 to 1154
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  653 non-null    object
#  1   END_DATE*    653 non-null    object
#  2   CATEGORY*    653 non-null    object
#  3   START*       653 non-null    object
#  4   STOP*        653 non-null    object
#  5   MILES*       653 non-null    float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 40.8+ KB

# %% [markdown]
# ## Q11. Get the unique start locations. (2 points)
# #### Note: This question is based on the dataframe with no 'NA' values

# %%
df['START*'].unique()
# Out:
# array(['Fort Pierce', 'West Palm Beach', 'Cary', 'Jamaica', 'New York',
#        'Elmhurst', 'Midtown', 'East Harlem', 'Flatiron District',
#        'Midtown East', 'Hudson Square', 'Lower Manhattan',
#        "Hell's Kitchen", 'Downtown', 'Gulfton', 'Houston', 'Eagan Park',
#        'Morrisville', 'Durham', 'Farmington Woods', 'Lake Wellingborough',
#        'Fayetteville Street', 'Raleigh', 'Whitebridge', 'Hazelwood',
#        'Fairmont', 'Meredith Townes', 'Apex', 'Chapel Hill', 'Northwoods',
#        'Edgehill Farms', 'Eastgate', 'East Elmhurst', 'Long Island City',
#        'Katunayaka', 'Colombo', 'Nugegoda', 'Unknown Location',
#        'Islamabad', 'R?walpindi', 'Noorpur Shahan', 'Preston',
#        'Heritage Pines', 'Tanglewood', 'Waverly Place', 'Wayne Ridge',
#        'Westpark Place', 'East Austin', 'The Drag', 'South Congress',
#        'Georgian Acres', 'North Austin', 'West University', 'Austin',
# ...

# %% [markdown]
# ## Q12. What is the total number of unique start destinations? (2 points)
# #### Note: Use the original dataframe without dropping 'NA' values

# %%
uber_drives['START*'].nunique()
# Out:
# 176

# %% [markdown]
# ## Q13. What is the total number of unique stop locations. (2 points)
# #### Note: Use the original dataframe without dropping 'NA' values.

# %%
uber_drives['STOP*'].nunique()
# Out:
# 187

# %% [markdown]
# ## Q14. Display all Uber trips that has the starting point as San Francisco. (2 points)
# #### Note: Use the original dataframe without dropping the 'NA' values.

# %%
uber_drives[uber_drives['START*'] == 'San Francisco']
# Out:
#           START_DATE*         END_DATE*  ... MILES*         PURPOSE*
# 362  05-09-2016 14:39  05-09-2016 15:06  ...   20.5  Between Offices
# 440   6/14/2016 16:09   6/14/2016 16:39  ...   11.6          Meeting
# 836  10/19/2016 14:02  10/19/2016 14:31  ...   10.8              NaN
# 917  11-07-2016 19:17  11-07-2016 19:57  ...   13.2  Between Offices
# 919  11-08-2016 12:16  11-08-2016 12:49  ...   11.3          Meeting
# 927  11-09-2016 18:40  11-09-2016 19:17  ...   12.7   Customer Visit
# 933  11-10-2016 15:17  11-10-2016 15:22  ...    9.9   Temporary Site
# 966  11/15/2016 20:44  11/15/2016 21:00  ...   11.8   Temporary Site
#
# [8 rows x 7 columns]

# %% [markdown]
# ## Q15. What is the most popular starting point for the Uber drivers? (2 points)
# #### Note: Use the original dataframe without dropping the 'NA' values.
#
# #### Hint:Popular means the place that is visited the most

# %%
uber_drives['START*'].value_counts().idxmax()
# Out:
# 'Cary'

# %% [markdown]
# ## Q16. What is the most popular dropping point for the Uber drivers? (2 points)
# #### Note: Use the original dataframe without dropping the 'NA' values.
#
# #### Hint: Popular means the place that is visited the most

# %%
uber_drives['STOP*'].value_counts().idxmax()
# Out:
# 'Cary'

# %% [markdown]
# ## Q17. What is the most frequent route taken by Uber drivers. (3 points)
# #### Note: This question is based on the new dataframe with no 'na' values.
# #### Hint-Print the most frequent route taken by Uber drivers (Route= combination of START & END points present in the Data set).

# %%
pd.DataFrame(df.groupby(['START*','STOP*'])['START_DATE*'].nunique()).sort_values(by = 'START_DATE*', ascending = False).head(1)
# Out:
#                     START_DATE*
# START* STOP*
# Cary   Morrisville           52

# %% [markdown]
# ## Q18. Display all types of purposes for the trip in an array. (2 points)
# #### Note: This question is based on the new dataframe with no 'NA' values.

# %%
df['PURPOSE*'].unique()
# Out:
# array(['Meal/Entertain', 'Errand/Supplies', 'Meeting', 'Customer Visit',
#        'Temporary Site', 'Between Offices', 'Charity ($)', 'Commute',
#        'Moving', 'Airport/Travel'], dtype=object)

# %% [markdown]
# ## Q19. Plot a bar graph of Purpose vs Miles(Distance). What can you infer from the plot(2 +2 points)
# #### Note: Use the original dataframe without dropping the 'NA' values.
# #### Hint:You have to plot total/sum miles per purpose

# %%
a=np.array(uber_drives.groupby("PURPOSE*").count().index)
plt.figure(figsize = (15,7))
plt.bar(a,uber_drives.groupby("PURPOSE*")["MILES*"].sum())
plt.show()

# %% [markdown]
# ## Q20. Display a dataframe of Purpose and the total distance travelled for that particular Purpose. (3 points)
# #### Note: Use the original dataframe without dropping "NA" values

# %%
pd.DataFrame(uber_drives.groupby('PURPOSE*')['MILES*'].sum())
# Out:
#                  MILES*
# PURPOSE*
# Airport/Travel     16.5
# Between Offices   197.0
# Charity ($)        15.1
# Commute           180.2
# Customer Visit   2089.5
# Errand/Supplies   508.0
# Meal/Entertain    911.7
# Meeting          2851.3
# Moving             18.2
# Temporary Site    523.7

# %% [markdown]
# ## Q21. Generate a plot showing count of trips vs category of trips. What can you infer from the plot (2 +1 points)
# #### Note: Use the original dataframe without dropping the 'NA' values.

# %%
a = np.array(uber_drives.groupby("CATEGORY*").count()["MILES*"])
print("number of business v/s personal trips",a)
plt.figure(figsize = (15,7))
plt.bar(uber_drives.groupby("CATEGORY*").count()["MILES*"].index,a)
plt.show()
# Out:
# number of business v/s personal trips [1078   77]

# %% [markdown]
# ## Q22. What percentage of Miles were clocked under Business Category and what percentage of Miles were clocked under Personal Category ? (3 points)
#
# ### Note:Use the original dataframe without dropping the 'NA' values.

# %%
b = pd.DataFrame(uber_drives.groupby('CATEGORY*')['MILES*'].sum())
c = uber_drives['MILES*'].sum()
b/c*100
# Out:
#               MILES*
# CATEGORY*
# Business   94.119479
# Personal    5.880521

# %% [markdown]
# ***THE END***
